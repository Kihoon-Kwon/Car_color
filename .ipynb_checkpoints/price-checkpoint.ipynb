# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import chromedriver_autoinstaller
import json # Json Object Array 이용
import requests # 호출 위함
import sys
import os
import re
import requests
import pandas as pd
import numpy as np

# %%
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)
url = 'https://www.hyundai.com/kr/ko/e/vehicles/ioniq6/price'
driver.get(url)
response = requests.get(url)

color_list = []
trim = driver.find_elements(By.CSS_SELECTOR,'#price-table > tbody > tr:nth-child(1) > th')
name = driver.find_element(By.CSS_SELECTOR,'#making > div.content-wrap > div > div > section.preview > div.preview-model > header > div.heading > span').text
color_list.append(name)
for i in range(1,len(x)+1):
    colors = driver.find_element(By.CSS_SELECTOR, '#pane-recomTab0 > div > ul > li:nth-child('+str(i)+') > div > div > span').text
    colors_text = driver.find_element(By.CSS_SELECTOR,'#pane-recomTab0 > div > ul > li:nth-child('+str(i)+') > p').text
    color_list.append(colors_text+' '+colors)
    
print(color_list)

driver.quit()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18236\3581505369.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# ['아이오닉 6 전기모터 Prestige(롱레인지) 20인치 4WD', '세레니티 화이트 펄 49%', '어비스블랙펄 16%', '그래비티 골드 매트 11%']

# %%
import time

chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)
url = 'https://www.hyundai.com/kr/ko/e/vehicles/ioniq6/price'
driver.get(url)
response = requests.get(url)


check = driver.find_element(By.CSS_SELECTOR,'#price-table > tbody > tr:nth-child(2) > td:nth-child(2) > div > div > label > i').click()

time.sleep(5)

driver.quit()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17616\1412245291.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)

# %%
'#price-table > tbody > tr:nth-child(1) > th'
'#price-table > tbody > tr:nth-child(2) > th'

'#price-table > tbody > tr:nth-child(2) > td:nth-child(2) > div > div > label > i'

# %%
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)

color_information=[]
for m1,m2 in zip(model,model_code):
    url = 'https://www.hyundai.com/kr/ko/e/vehicles/estimation/model/making?model='+m1+'&modelCode='+m2
    driver.get(url)
    response = requests.get(url)
    html = response.text
    
    color_list = []
    x = driver.find_elements(By.CSS_SELECTOR,'#pane-recomTab0 > div > ul > li')
    name = driver.find_element(By.CSS_SELECTOR,'#making > div.header-wrap > header > div.logo-wrap > button > span').text
    model = driver.find_element(By.CSS_SELECTOR,'#making > div.content-wrap > div > div > section.preview > div.preview-model > header > div.heading > span').text
    color_list.append(name)
    color_list.append(model)
    for i in range(1,len(x)+1):
        colors = driver.find_element(By.CSS_SELECTOR, '#pane-recomTab0 > div > ul > li:nth-child('+str(i)+') > div > div > span').text
        colors_text = driver.find_element(By.CSS_SELECTOR,'#pane-recomTab0 > div > ul > li:nth-child('+str(i)+') > p').text
        color_list.append(colors_text+' '+colors)
    color_information.append(color_list)
        
color_information
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18236\2119006717.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# [['스타리아 라운지 모빌리티',
#   '스타리아 라운지 모빌리티 영업용 7인승 LPG 3.5 2WD 오토 모빌리티',
#   '크리미 화이트 95%',
#   '어비스블랙펄 4%'],
#  ['스타리아',
#   '스타리아 자가용 5인승 LPG 3.5 2WD 오토 Modern',
#   '그라파이트 그레이 메탈릭 36%',
#   '크리미 화이트 21%',
#   '쉬머링 실버 메탈릭 16%'],
#  ['스타리아 라운지',
#   '스타리아 라운지 자가용 7인승 디젤 4WD 오토 Inspiration',
#   '어비스블랙펄 44%',
#   '크리미 화이트 41%',
#   '쉬머링 실버 메탈릭 5%'],
#  ['스타리아 라운지 캠퍼',
#   '스타리아 라운지 캠퍼 Camper4 4인승 디젤 4WD 오토 Prestige',
#   '크리미 화이트 71%',
#   '어비스블랙펄 28%'],
#  ['스타리아 라운지 리무진',
#   '스타리아 라운지 리무진 리무진 9인승 디젤 4WD 오토 Inspiration',
#   '크리미 화이트 50%',
#   '어비스블랙펄 50%'],
#  ['스타리아 킨더', '스타리아 킨더 어린이보호차 11인승 LPG 3.5 2WD 오토 Modern', '다이나믹 옐로우 100%'],
#  ['쏘나타 택시',
#   '쏘나타 택시 LPi 2.0 오토 경제형(NS) 뉴라이즈',
#   '큐레이티드 실버 메탈릭 65%',
#   '아틀라스 화이트 34%',
#   '어비스블랙펄 0%'],
#  ['쏘나타 N Line',
#   '쏘나타 N Line 자가용 가솔린 2.5 T-GDi(N라인) N Line',
#   '큐레이티드 실버 메탈릭 50%',
#   '어비스블랙펄 50%'],
#  ['쏘나타 Hybrid',
#   '쏘나타 Hybrid 자가용 하이브리드 2.0 Premium Plus',
#   '세레니티 화이트 펄 46%',
#   '녹턴 그레이 메탈릭 37%',
#   '어비스블랙펄 10%'],
#  ['쏘나타',
#   '쏘나타 자가용 가솔린 2.0 Premium Plus',
#   '녹턴 그레이 메탈릭 50%',
#   '세레니티 화이트 펄 28%',
#   '어비스블랙펄 11%'],
#  ['넥쏘',
#   '넥쏘 자가용 5인승 수소전기 오토 Premium',
#   '크리미 화이트 펄 42%',
#   '티타늄 그레이 매트 28%',
#   '오션 인디고 펄 15%'],
#  ['팰리세이드',
#   '팰리세이드 가솔린 3.8 2WD 오토 Calligraphy 7인승 캘리전용퀼팅나파(블랙)',
#   '크리미 화이트 펄 53%',
#   '어비스블랙펄 19%',
#   '로버스트 에메랄드 펄 11%'],
#  ['싼타페',
#   '싼타페 가솔린 2.5 2WD 오토 Calligraphy 5인승',
#   '크리미 화이트 펄 50%',
#   '마그네틱 그레이 메탈릭 18%',
#   '어비스블랙펄 8%'],
#  ['싼타페 Hybrid',
#   '싼타페 Hybrid 하이브리드 2WD 오토 Calligraphy 5인승',
#   '크리미 화이트 펄 53%',
#   '마그네틱 그레이 메탈릭 15%',
#   '어비스블랙펄 9%'],
#  ['베뉴',
#   '베뉴 가솔린 1.6 PREMIUM 2WD IVT',
#   '아틀라스 화이트 21%',
#   '데님 블루 펄 16%',
#   '에코트로닉 그레이펄 15%'],
#  ['투싼',
#   '투싼 1.6 가솔린 터보 Inspiration 2WD DCT',
#   '아마존 그레이 메탈릭 35%',
#   '크리미 화이트 펄 30%',
#   '티탄 그레이 메탈릭 17%'],
#  ['투싼 Hybrid',
#   '투싼 Hybrid 하이브리드 Inspiration 2WD A/T',
#   '크리미 화이트 펄 42%',
#   '아마존 그레이 메탈릭 29%',
#   '티탄 그레이 메탈릭 15%'],
#  ['투싼',
#   '투싼 1.6 가솔린 터보 Inspiration 2WD DCT',
#   '아마존 그레이 메탈릭 35%',
#   '크리미 화이트 펄 30%',
#   '티탄 그레이 메탈릭 17%'],
#  ['투싼 Hybrid',
#   '투싼 Hybrid 하이브리드 Inspiration 2WD A/T',
#   '크리미 화이트 펄 42%',
#   '아마존 그레이 메탈릭 29%',
#   '티탄 그레이 메탈릭 15%'],
#  ['아이오닉 5',
#   '아이오닉 5 전기차 Prestige(롱레인지) 20인치 오토',
#   '아틀라스 화이트 40%',
#   '그래비티 골드 매트 14%',
#   '사이버 그레이 메탈릭 13%'],
#  ['아이오닉 6',
#   '아이오닉 6 전기모터 Prestige(롱레인지) 20인치 4WD',
#   '세레니티 화이트 펄 49%',
#   '어비스블랙펄 16%',
#   '그래비티 골드 매트 11%'],
#  ['디 올 뉴 그랜저 택시',
#   '디 올 뉴 그랜저 택시 택시 LPi 3.5 고급형 2WD',
#   '세레니티 화이트 펄 45%',
#   '큐레이티드 실버 메탈릭 30%',
#   '어비스블랙펄 23%'],
#  ['디 올 뉴 그랜저 Hybrid',
#   '디 올 뉴 그랜저 Hybrid 자가용 하이브리드 1.6T 캘리그래피 2WD',
#   '어비스블랙펄 33%',
#   '세레니티 화이트 펄 30%',
#   '녹턴 그레이 메탈릭 17%'],
#  ['디 올 뉴 그랜저',
#   '디 올 뉴 그랜저 자가용 가솔린 2.5 익스클루시브 2WD',
#   '세레니티 화이트 펄 29%',
#   '어비스블랙펄 28%',
#   '녹턴 그레이 메탈릭 27%']]

# %%
driver.quit()

# %%
for color_info in color_information:
    if len(color_info)==3:
        color_info.append('-')
        color_info.append('-')
    elif len(color_info)==4:
        color_info.append('-')
    else:
        pass
    
color_information
# Out:
# [['스타리아 라운지 모빌리티',
#   '스타리아 라운지 모빌리티 영업용 7인승 LPG 3.5 2WD 오토 모빌리티',
#   '크리미 화이트 95%',
#   '어비스블랙펄 4%',
#   '-'],
#  ['스타리아',
#   '스타리아 자가용 5인승 LPG 3.5 2WD 오토 Modern',
#   '그라파이트 그레이 메탈릭 36%',
#   '크리미 화이트 21%',
#   '쉬머링 실버 메탈릭 16%'],
#  ['스타리아 라운지',
#   '스타리아 라운지 자가용 7인승 디젤 4WD 오토 Inspiration',
#   '어비스블랙펄 44%',
#   '크리미 화이트 41%',
#   '쉬머링 실버 메탈릭 5%'],
#  ['스타리아 라운지 캠퍼',
#   '스타리아 라운지 캠퍼 Camper4 4인승 디젤 4WD 오토 Prestige',
#   '크리미 화이트 71%',
#   '어비스블랙펄 28%',
#   '-'],
#  ['스타리아 라운지 리무진',
#   '스타리아 라운지 리무진 리무진 9인승 디젤 4WD 오토 Inspiration',
#   '크리미 화이트 50%',
#   '어비스블랙펄 50%',
#   '-'],
#  ['스타리아 킨더',
#   '스타리아 킨더 어린이보호차 11인승 LPG 3.5 2WD 오토 Modern',
#   '다이나믹 옐로우 100%',
#   '-',
#   '-'],
#  ['쏘나타 택시',
#   '쏘나타 택시 LPi 2.0 오토 경제형(NS) 뉴라이즈',
#   '큐레이티드 실버 메탈릭 65%',
#   '아틀라스 화이트 34%',
#   '어비스블랙펄 0%'],
#  ['쏘나타 N Line',
#   '쏘나타 N Line 자가용 가솔린 2.5 T-GDi(N라인) N Line',
#   '큐레이티드 실버 메탈릭 50%',
#   '어비스블랙펄 50%',
#   '-'],
#  ['쏘나타 Hybrid',
#   '쏘나타 Hybrid 자가용 하이브리드 2.0 Premium Plus',
#   '세레니티 화이트 펄 46%',
#   '녹턴 그레이 메탈릭 37%',
#   '어비스블랙펄 10%'],
#  ['쏘나타',
#   '쏘나타 자가용 가솔린 2.0 Premium Plus',
#   '녹턴 그레이 메탈릭 50%',
#   '세레니티 화이트 펄 28%',
#   '어비스블랙펄 11%'],
#  ['넥쏘',
#   '넥쏘 자가용 5인승 수소전기 오토 Premium',
#   '크리미 화이트 펄 42%',
#   '티타늄 그레이 매트 28%',
#   '오션 인디고 펄 15%'],
#  ['팰리세이드',
#   '팰리세이드 가솔린 3.8 2WD 오토 Calligraphy 7인승 캘리전용퀼팅나파(블랙)',
#   '크리미 화이트 펄 53%',
#   '어비스블랙펄 19%',
#   '로버스트 에메랄드 펄 11%'],
#  ['싼타페',
#   '싼타페 가솔린 2.5 2WD 오토 Calligraphy 5인승',
#   '크리미 화이트 펄 50%',
#   '마그네틱 그레이 메탈릭 18%',
#   '어비스블랙펄 8%'],
#  ['싼타페 Hybrid',
#   '싼타페 Hybrid 하이브리드 2WD 오토 Calligraphy 5인승',
#   '크리미 화이트 펄 53%',
#   '마그네틱 그레이 메탈릭 15%',
#   '어비스블랙펄 9%'],
#  ['베뉴',
#   '베뉴 가솔린 1.6 PREMIUM 2WD IVT',
#   '아틀라스 화이트 21%',
#   '데님 블루 펄 16%',
#   '에코트로닉 그레이펄 15%'],
#  ['투싼',
#   '투싼 1.6 가솔린 터보 Inspiration 2WD DCT',
#   '아마존 그레이 메탈릭 35%',
#   '크리미 화이트 펄 30%',
#   '티탄 그레이 메탈릭 17%'],
#  ['투싼 Hybrid',
#   '투싼 Hybrid 하이브리드 Inspiration 2WD A/T',
#   '크리미 화이트 펄 42%',
#   '아마존 그레이 메탈릭 29%',
#   '티탄 그레이 메탈릭 15%'],
#  ['투싼',
#   '투싼 1.6 가솔린 터보 Inspiration 2WD DCT',
#   '아마존 그레이 메탈릭 35%',
#   '크리미 화이트 펄 30%',
#   '티탄 그레이 메탈릭 17%'],
#  ['투싼 Hybrid',
#   '투싼 Hybrid 하이브리드 Inspiration 2WD A/T',
#   '크리미 화이트 펄 42%',
#   '아마존 그레이 메탈릭 29%',
#   '티탄 그레이 메탈릭 15%'],
#  ['아이오닉 5',
#   '아이오닉 5 전기차 Prestige(롱레인지) 20인치 오토',
#   '아틀라스 화이트 40%',
#   '그래비티 골드 매트 14%',
#   '사이버 그레이 메탈릭 13%'],
#  ['아이오닉 6',
#   '아이오닉 6 전기모터 Prestige(롱레인지) 20인치 4WD',
#   '세레니티 화이트 펄 49%',
#   '어비스블랙펄 16%',
#   '그래비티 골드 매트 11%'],
#  ['디 올 뉴 그랜저 택시',
#   '디 올 뉴 그랜저 택시 택시 LPi 3.5 고급형 2WD',
#   '세레니티 화이트 펄 45%',
#   '큐레이티드 실버 메탈릭 30%',
#   '어비스블랙펄 23%'],
#  ['디 올 뉴 그랜저 Hybrid',
#   '디 올 뉴 그랜저 Hybrid 자가용 하이브리드 1.6T 캘리그래피 2WD',
#   '어비스블랙펄 33%',
#   '세레니티 화이트 펄 30%',
#   '녹턴 그레이 메탈릭 17%'],
#  ['디 올 뉴 그랜저',
#   '디 올 뉴 그랜저 자가용 가솔린 2.5 익스클루시브 2WD',
#   '세레니티 화이트 펄 29%',
#   '어비스블랙펄 28%',
#   '녹턴 그레이 메탈릭 27%']]

# %%
columns = ['name','model','color_1st','color_2nd','color_3rd']
df_color = pd.DataFrame(color_information,columns=columns)
df_color
# Out:
#                 name                                              model  \
# 0      스타리아 라운지 모빌리티          스타리아 라운지 모빌리티 영업용 7인승 LPG 3.5 2WD 오토 모빌리티
# 1               스타리아                 스타리아 자가용 5인승 LPG 3.5 2WD 오토 Modern
# 2           스타리아 라운지             스타리아 라운지 자가용 7인승 디젤 4WD 오토 Inspiration
# 3        스타리아 라운지 캠퍼         스타리아 라운지 캠퍼 Camper4 4인승 디젤 4WD 오토 Prestige
# 4       스타리아 라운지 리무진         스타리아 라운지 리무진 리무진 9인승 디젤 4WD 오토 Inspiration
# 5            스타리아 킨더          스타리아 킨더 어린이보호차 11인승 LPG 3.5 2WD 오토 Modern
# 6             쏘나타 택시                     쏘나타 택시 LPi 2.0 오토 경제형(NS) 뉴라이즈
# 7         쏘나타 N Line           쏘나타 N Line 자가용 가솔린 2.5 T-GDi(N라인) N Line
# 8         쏘나타 Hybrid              쏘나타 Hybrid 자가용 하이브리드 2.0 Premium Plus
# 9                쏘나타                       쏘나타 자가용 가솔린 2.0 Premium Plus
# 10                넥쏘                         넥쏘 자가용 5인승 수소전기 오토 Premium
# 11             팰리세이드  팰리세이드 가솔린 3.8 2WD 오토 Calligraphy 7인승 캘리전용퀼팅나파(블랙)
# 12               싼타페                 싼타페 가솔린 2.5 2WD 오토 Calligraphy 5인승
# 13        싼타페 Hybrid            싼타페 Hybrid 하이브리드 2WD 오토 Calligraphy 5인승
# 14                베뉴                         베뉴 가솔린 1.6 PREMIUM 2WD IVT
# 15                투싼                  투싼 1.6 가솔린 터보 Inspiration 2WD DCT
# 16         투싼 Hybrid                투싼 Hybrid 하이브리드 Inspiration 2WD A/T
# 17                투싼                  투싼 1.6 가솔린 터보 Inspiration 2WD DCT
# 18         투싼 Hybrid                투싼 Hybrid 하이브리드 Inspiration 2WD A/T
# 19            아이오닉 5                  아이오닉 5 전기차 Prestige(롱레인지) 20인치 오토
# 20            아이오닉 6                아이오닉 6 전기모터 Prestige(롱레인지) 20인치 4WD
# 21      디 올 뉴 그랜저 택시                    디 올 뉴 그랜저 택시 택시 LPi 3.5 고급형 2WD
# 22  디 올 뉴 그랜저 Hybrid          디 올 뉴 그랜저 Hybrid 자가용 하이브리드 1.6T 캘리그래피 2WD
# 23         디 올 뉴 그랜저                   디 올 뉴 그랜저 자가용 가솔린 2.5 익스클루시브 2WD
#
#             color_1st         color_2nd        color_3rd
# 0         크리미 화이트 95%         어비스블랙펄 4%                -
# 1   그라파이트 그레이 메탈릭 36%       크리미 화이트 21%   쉬머링 실버 메탈릭 16%
# 2          어비스블랙펄 44%       크리미 화이트 41%    쉬머링 실버 메탈릭 5%
# 3         크리미 화이트 71%        어비스블랙펄 28%                -
# 4         크리미 화이트 50%        어비스블랙펄 50%                -
# 5       다이나믹 옐로우 100%                 -                -
# 6    큐레이티드 실버 메탈릭 65%      아틀라스 화이트 34%        어비스블랙펄 0%
# 7    큐레이티드 실버 메탈릭 50%        어비스블랙펄 50%                -
# 8      세레니티 화이트 펄 46%    녹턴 그레이 메탈릭 37%       어비스블랙펄 10%
# 9      녹턴 그레이 메탈릭 50%    세레니티 화이트 펄 28%       어비스블랙펄 11%
# 10      크리미 화이트 펄 42%    티타늄 그레이 매트 28%     오션 인디고 펄 15%
# 11      크리미 화이트 펄 53%        어비스블랙펄 19%  로버스트 에메랄드 펄 11%
# 12      크리미 화이트 펄 50%  마그네틱 그레이 메탈릭 18%        어비스블랙펄 8%
# 13      크리미 화이트 펄 53%  마그네틱 그레이 메탈릭 15%        어비스블랙펄 9%
# 14       아틀라스 화이트 21%       데님 블루 펄 16%   에코트로닉 그레이펄 15%
# 15    아마존 그레이 메탈릭 35%     크리미 화이트 펄 30%   티탄 그레이 메탈릭 17%
# 16      크리미 화이트 펄 42%   아마존 그레이 메탈릭 29%   티탄 그레이 메탈릭 15%
# 17    아마존 그레이 메탈릭 35%     크리미 화이트 펄 30%   티탄 그레이 메탈릭 17%
# 18      크리미 화이트 펄 42%   아마존 그레이 메탈릭 29%   티탄 그레이 메탈릭 15%
# 19       아틀라스 화이트 40%    그래비티 골드 매트 14%  사이버 그레이 메탈릭 13%
# 20     세레니티 화이트 펄 49%        어비스블랙펄 16%   그래비티 골드 매트 11%
# 21     세레니티 화이트 펄 45%  큐레이티드 실버 메탈릭 30%       어비스블랙펄 23%
# 22         어비스블랙펄 33%    세레니티 화이트 펄 30%   녹턴 그레이 메탈릭 17%
# 23     세레니티 화이트 펄 29%        어비스블랙펄 28%   녹턴 그레이 메탈릭 27%

# %%
df_color.to_csv('0331_test.csv',encoding='cp949')
