# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import chromedriver_autoinstaller
import json # Json Object Array 이용
import requests # 호출 위함
import sys
import os
import re
import requests
import pandas as pd
import numpy as np

# %%
# 현대자동차 전체 모델 리스트

car_codes = pd.read_csv('차종-모델 코드.csv',encoding='utf-8')
car_codes
# Out:
#                 name model                   best trim  modelCode
# 0     더 뉴 아반떼 hybrid  CN13                          없음         없음
# 1            더 뉴 아반떼  CN12                          없음         없음
# 2      스타리아 라운지 모빌리티  US11      영업용 7인승 LPG 3.5 2WD 오토  USTL7LBT2
# 3              아반떼 N  CN06                          없음         없음
# 4               스타리아  US09      자가용 5인승 LPG 3.5 2WD 오토  USJC5LMT2
# 5           스타리아 라운지  US10           자가용 7인승 디젤 4WD 오토  USJL7DEA2
# 6        스타리아 라운지 캠퍼  US12       Camper4 4인승 디젤 4WD 오토  USGL4DPA2
# 7       스타리아 라운지 리무진  US13           리무진 9인승 디젤 4WD 오토  USLL9DEA2
# 8            스타리아 킨더  US14  어린이보호차 11인승 LPG 3.5 2WD 오토  USCTBLMT2
# 9             쏘나타 택시  GF19             LPi 2.0 오토 뉴라이즈  GFTS4LPT8
# 10        쏘나타 N line  DN14      자가용 가솔린 2.5 T-GDi(N라인)  DNJS4NLT4
# 11        쏘나타 Hybrid  DN13               자가용 하이브리드 2.0  DNJS4ZPT4
# 12               쏘나타  DN12          자가용 스마트스트림 가솔린 2.0  DNJS4SPT4
# ...

# %%
# best trim 없는 차량 삭제

car_codes = car_codes[car_codes.modelCode!='없음']
car_codes
# Out:
#                 name model                   best trim  modelCode
# 2      스타리아 라운지 모빌리티  US11      영업용 7인승 LPG 3.5 2WD 오토  USTL7LBT2
# 4               스타리아  US09      자가용 5인승 LPG 3.5 2WD 오토  USJC5LMT2
# 5           스타리아 라운지  US10           자가용 7인승 디젤 4WD 오토  USJL7DEA2
# 6        스타리아 라운지 캠퍼  US12       Camper4 4인승 디젤 4WD 오토  USGL4DPA2
# 7       스타리아 라운지 리무진  US13           리무진 9인승 디젤 4WD 오토  USLL9DEA2
# 8            스타리아 킨더  US14  어린이보호차 11인승 LPG 3.5 2WD 오토  USCTBLMT2
# 9             쏘나타 택시  GF19             LPi 2.0 오토 뉴라이즈  GFTS4LPT8
# 10        쏘나타 N line  DN14      자가용 가솔린 2.5 T-GDi(N라인)  DNJS4NLT4
# 11        쏘나타 Hybrid  DN13               자가용 하이브리드 2.0  DNJS4ZPT4
# 12               쏘나타  DN12          자가용 스마트스트림 가솔린 2.0  DNJS4SPT4
# 13                넥쏘  FE03             자가용 5인승 수소전기 오토  FEJJ5HBT2
# 14             팰리세이드  LX05          가솔린 3.8 2WD 오토 7인승  LXJJ7MCT4
# 15               싼타페  TM09          가솔린 2.5 오토 2WD 5인승  TMJJ5THT6
# ...

# %%
model = car_codes['model'].values.tolist()
model_code = car_codes['modelCode'].values.tolist()
print(model)
print(model_code)
print(len(model))
print(len(model_code))
# Out:
# ['US11', 'US09', 'US10', 'US12', 'US13', 'US14', 'GF19', 'DN14', 'DN13', 'DN12', 'FE03', 'LX05', 'TM09', 'TM10', 'QX05', 'NX05', 'NX06', 'NX07', 'NX08', 'NE02', 'CE01', 'GN03', 'GN02', 'GN01']
# ['USTL7LBT2', 'USJC5LMT2', 'USJL7DEA2', 'USGL4DPA2', 'USLL9DEA2', 'USCTBLMT2', 'GFTS4LPT8', 'DNJS4NLT4', 'DNJS4ZPT4', 'DNJS4SPT4', 'FEJJ5HBT2', 'LXJJ7MCT4', 'TMJJ5THT6', 'TMJJ5ZHT6', 'QXJJ5GDC4', 'NXJJ5TPD2', 'NXJJ5ZPT2', 'NXJJ5TPD2', 'NXJJ5ZPT2', 'NEJJ5VBA2', 'CEJS4VGA1', 'GNTS4LVT1', 'GNJS4ZCT1', 'GNJS4RBT1']
# 24
# 24

# %%
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)

tbody = '#pane-recomTab0 > div > ul'
x = driver.find_elements(By.CSS_SELECTOR,'#pane-recomTab0 > div > ul > li')
'#pane-recomTab0 > div > ul > li:nth-child(1) > div > div > span'

for m1,m2 in zip(model,model_code):
    url = 'https://www.hyundai.com/kr/ko/e/vehicles/estimation/model/making?model='+m1+'&modelCode='+m2
    driver.get(url)
    response = requests.get(url)
    html = response.text
    x = driver.find_elements(By.CSS_SELECTOR,'#pane-recomTab0 > div > ul > li')
    for i in range(1,len(x)+1):
        colors = driver.find_element(By.CSS_SELECTOR, '#pane-recomTab0 > div > ul > li:nth-child('+i+') > div > div > span').text
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16476\2001486980.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 4>()
#       5 url = 'https://www.hyundai.com/kr/ko/e/vehicles/estimation/model/making?model='+m1+'&modelCode='+m2
#       6 driver.get(url)
# ----> 7 response = requests.get(url)
#       8 html = response.text
#
# File ~\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
driver.quit()
